# %%
import pandas as pd
import re

# %%
df = pd.read_csv("Cleaned_Dataset.csv")

# %%
df
# Out:
#        release_date                                 name  \
# 0        1922-02-22                                Carve
# 1        1922-06-01  Capítulo 2.16 - Banquero Anarquista
# 2        1922-03-21   Vivo para Quererte - Remasterizado
# 3        1922-03-21        El Prisionero - Remasterizado
# 4        1922-01-01                  Lady of the Evening
# ...             ...                                  ...
# 584698   2020-09-26                                  云与海
# 584699   2020-10-21                                blind
# 584700   2020-09-02            What They'll Say About Us
# 584701   2021-03-05                      A Day At A Time
# 584702   2015-07-01                     Mar de Emociones
#
#                                 artists  year  duration  explicit  popularity  \
# 0                               ['Uli']  1922       127         0           6
# 1                   ['Fernando Pessoa']  1922        98         0           0
# ...

# %%
df["artists"].dtype
# Out:
# dtype('O')

# %%
df["artists"] = df["artists"].str.strip(to_strip = "[]")

# %%
df["artists"] = df["artists"].str.strip(to_strip = "'")

# %%
df["artists"] = df["artists"].str.replace("'","")

# %%
df["artists"]
# Out:
# 0                               Uli
# 1                   Fernando Pessoa
# 2                   Ignacio Corsini
# 3                   Ignacio Corsini
# 4                       Dick Haymes
#                     ...
# 584698                      阿YueYue
# 584699                   ROLE MODEL
# 584700                      FINNEAS
# 584701    Gentle Bones, Clara Benin
# 584702                    Afrosound
# Name: artists, Length: 584703, dtype: object

# %%
df
# Out:
#        release_date                                 name  \
# 0        1922-02-22                                Carve
# 1        1922-06-01  Capítulo 2.16 - Banquero Anarquista
# 2        1922-03-21   Vivo para Quererte - Remasterizado
# 3        1922-03-21        El Prisionero - Remasterizado
# 4        1922-01-01                  Lady of the Evening
# ...             ...                                  ...
# 584698   2020-09-26                                  云与海
# 584699   2020-10-21                                blind
# 584700   2020-09-02            What They'll Say About Us
# 584701   2021-03-05                      A Day At A Time
# 584702   2015-07-01                     Mar de Emociones
#
#                           artists  year  duration  explicit  popularity  \
# 0                             Uli  1922       127         0           6
# 1                 Fernando Pessoa  1922        98         0           0
# ...

# %%
df = df[df['year'] >= 1910]
df
# Out:
#        release_date                                 name  \
# 0        1922-02-22                                Carve
# 1        1922-06-01  Capítulo 2.16 - Banquero Anarquista
# 2        1922-03-21   Vivo para Quererte - Remasterizado
# 3        1922-03-21        El Prisionero - Remasterizado
# 4        1922-01-01                  Lady of the Evening
# ...             ...                                  ...
# 584698   2020-09-26                                  云与海
# 584699   2020-10-21                                blind
# 584700   2020-09-02            What They'll Say About Us
# 584701   2021-03-05                      A Day At A Time
# 584702   2015-07-01                     Mar de Emociones
#
#                           artists  year  duration  explicit  popularity  \
# 0                             Uli  1922       127         0           6
# 1                 Fernando Pessoa  1922        98         0           0
# ...

# %%
df = df.set_index("release_date")

# %%
df
# Out:
#                                              name                    artists  \
# release_date
# 1922-02-22                                  Carve                        Uli
# 1922-06-01    Capítulo 2.16 - Banquero Anarquista            Fernando Pessoa
# 1922-03-21     Vivo para Quererte - Remasterizado            Ignacio Corsini
# 1922-03-21          El Prisionero - Remasterizado            Ignacio Corsini
# 1922-01-01                    Lady of the Evening                Dick Haymes
# ...                                           ...                        ...
# 2020-09-26                                    云与海                    阿YueYue
# 2020-10-21                                  blind                 ROLE MODEL
# 2020-09-02              What They'll Say About Us                    FINNEAS
# 2021-03-05                        A Day At A Time  Gentle Bones, Clara Benin
# 2015-07-01                       Mar de Emociones                  Afrosound
#
# ...

# %%
df.describe()
# Out:
#                 year       duration       explicit     popularity  \
# count  584702.000000  584702.000000  584702.000000  584702.000000
# mean     1988.585025     230.046386       0.044074      27.642377
# std        22.760645     126.438428       0.205259      18.338856
# min      1922.000000       3.000000       0.000000       0.000000
# 25%      1974.000000     175.000000       0.000000      13.000000
# 50%      1992.000000     215.000000       0.000000      27.000000
# 75%      2007.000000     264.000000       0.000000      41.000000
# max      2021.000000    5621.000000       1.000000     100.000000
#
#         danceability         energy       loudness    speechiness  \
# count  584702.000000  584702.000000  584702.000000  584702.000000
# mean        0.563586       0.542199     -10.203902       0.104945
# std         0.165971       0.251726       5.078082       0.180131
# min         0.000000       0.000000     -60.000000       0.000000
# ...

# %%
df.to_csv("Fixed_Dataset.csv")
